# %% [markdown]
# # Accessing Data from Pandas Data structures

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("IMDB-Movie-Data.csv")
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df["Rank"]
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 995     996
# 996     997
# 997     998
# 998     999
# 999    1000
# Name: Rank, Length: 1000, dtype: int64

# %%
df.iloc[2]
# Out:
# Rank                                                                  3
# Title                                                             Split
# Genre                                                   Horror,Thriller
# Description           Three girls are kidnapped by a man with a diag...
# Director                                             M. Night Shyamalan
# Actors                James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Year                                                               2016
# Runtime (Minutes)                                                   117
# Rating                                                              7.3
# Votes                                                            157606
# Revenue (Millions)                                               138.12
# Metascore                                                            62
# Name: 2, dtype: object

# %%
#The other main approach is to pass a value from your dataframe's index to the .loc method:
df.loc[2]
# Out:
# Rank                                                                  3
# Title                                                             Split
# Genre                                                   Horror,Thriller
# Description           Three girls are kidnapped by a man with a diag...
# Director                                             M. Night Shyamalan
# Actors                James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Year                                                               2016
# Runtime (Minutes)                                                   117
# Rating                                                              7.3
# Votes                                                            157606
# Revenue (Millions)                                               138.12
# Metascore                                                            62
# Name: 2, dtype: object

# %%
df.iloc[[3, 2, 1]]
# Out:
#    Rank       Title                     Genre  \
# 3     4        Sing   Animation,Comedy,Family
# 2     3       Split           Horror,Thriller
# 1     2  Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description              Director  \
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 3     7.2   60545              270.32       59.0
# 2     7.3  157606              138.12       62.0
# ...

# %%
df[:3]
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %%
df[3:6]
# Out:
#    Rank           Title                     Genre  \
# 3     4            Sing   Animation,Comedy,Family
# 4     5   Suicide Squad  Action,Adventure,Fantasy
# 5     6  The Great Wall  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
# 5  European mercenaries searching for black powde...           Yimou Zhang
#
#                                               Actors  Year  Runtime (Minutes)  \
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
# 5      Matt Damon, Tian Jing, Willem Dafoe, Andy Lau  2016                103
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 3     7.2   60545              270.32       59.0
# ...

# %%
df[['Title', 'Votes', 'Rating']][:3]
# Out:
#                      Title   Votes  Rating
# 0  Guardians of the Galaxy  757074     8.1
# 1               Prometheus  485820     7.0
# 2                    Split  157606     7.3

# %%
df.Title.iloc[2]
# Out:
# 'Split'

# %%
df.Title.iloc[[2]]
# Out:
# 2    Split
# Name: Title, dtype: object

# %%
(df.Rating > 7).head()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Rating, dtype: bool

# %%
df[df.Rating > 7].head()
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 6     7               La La Land          Comedy,Drama,Music
# 8     9       The Lost City of Z  Action,Adventure,Biography
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 6  A jazz pianist falls for an aspiring actress i...       Damien Chazelle
# 8  A true-life drama, centering on British explor...            James Gray
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df[(df.Year > 2015) | (df.Director == 'James Gray')].head(3)
# Out:
#    Rank          Title                     Genre  \
# 2     3          Split           Horror,Thriller
# 3     4           Sing   Animation,Comedy,Family
# 4     5  Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 2     7.3  157606              138.12       62.0
# 3     7.2   60545              270.32       59.0
# ...

# %%
df[df['Title'].str.split().apply(lambda x: len(x) == 3)].head(3)
# Out:
#     Rank           Title                     Genre  \
# 5      6  The Great Wall  Action,Adventure,Fantasy
# 6      7      La La Land        Comedy,Drama,Music
# 22    23  Hounds of Love        Crime,Drama,Horror
#
#                                           Description         Director  \
# 5   European mercenaries searching for black powde...      Yimou Zhang
# 6   A jazz pianist falls for an aspiring actress i...  Damien Chazelle
# 22  A cold-blooded predatory couple while cruising...        Ben Young
#
#                                                Actors  Year  \
# 5       Matt Damon, Tian Jing, Willem Dafoe, Andy Lau  2016
# 6   Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....  2016
# 22  Emma Booth, Ashleigh Cummings, Stephen Curry,S...  2016
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 5                 103     6.1   56036               45.13       42.0
# 6                 128     8.3  258682              151.06       93.0
# ...

# %% [markdown]
# # Data cleaning

# %%
# removing duplicates rows
series = df.duplicated()
series
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 993    False
# 994    False
# 996    False
# 997    False
# 999    False
# Length: 838, dtype: bool

# %%
df.drop_duplicates(inplace = True)
df.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %% [markdown]
# # Data Aggregation

# %%
df.agg(['min','max'])
# Out:
#      Rank                 Title     Genre  \
# min     1  (500) Days of Summer    Action
# max  1000              Zootopia  Thriller
#
#                                            Description       Director  \
# min  "21" is the fact-based story about six MIT stu...     Aamir Khan
# max  Young, up-and-coming martial artist, Bruce Lee...  Zackary Adler
#
#                                                 Actors  Year  \
# min  Aamir Khan, Anushka Sharma, Sanjay Dutt,Boman ...  2006
# max  Zooey Deschanel, Joseph Gordon-Levitt, Geoffre...  2016
#
#      Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# min                 66     1.9      178                0.00       11.0
# max                187     9.0  1791916              936.63      100.0

# %%
df['Rating'].max()
# Out:
# 9.0

# %%
df['Rating'].mean()
# Out:
# 6.814319809069212

# %%
df['Rating'].median()
# Out:
# 6.9

# %%
df['Rating'].sum()
# Out:
# 5710.4

# %%
df['Rating'].std()
# Out:
# 0.8777538418027492

# %% [markdown]
# # Data Merging
# 1. Inner Join or Natural join: To keep only rows that match from the data frames, specify the argument how=‘inner’.
# 2. Outer Join or Full outer join:To keep all rows from both data frames, specify how=‘outer’.
# 3. Left Join or Left outer join:To include all the rows of your data frame x and only those from y that match, specify how=‘left’.
# 4. Right Join or Right outer join:To include all the rows of your data frame y and only those from x that match, specify how=‘right’.

# %%
d1 = {'Customer_id':pd.Series([1,2,3,4,5,6]),
  'Product':pd.Series(['Oven','Oven','Oven','Television','Television','Television'])}
df1 = pd.DataFrame(d1)
# data frame 2
d2 = {'Customer_id':pd.Series([2,4,6,7,8]),
    'State':pd.Series(['California','California','Texas','New York','Indiana'])}
df2 = pd.DataFrame(d2)

# %%
inner_join_df= pd.merge(df1, df2, on='Customer_id', how='inner')
inner_join_df
# Out:
#    Customer_id     Product       State
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas

# %%
outer_join_df=pd.merge(df1, df2, on='Customer_id', how='outer')
outer_join_df
# Out:
#    Customer_id     Product       State
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas
# 6            7         NaN    New York
# 7            8         NaN     Indiana

# %%
left_join_df= pd.merge(df1, df2, on='Customer_id', how='left')
left_join_df
# Out:
#    Customer_id     Product       State
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas

# %%
right_join_df= pd.merge(df1, df2, on='Customer_id', how='right')
right_join_df
# Out:
#    Customer_id     Product       State
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas
# 3            7         NaN    New York
# 4            8         NaN     Indiana

# %%
import matplotlib.pyplot as plt
df.plot()
plt.show()
